# %% [markdown]
# ### AI-INVASION KADUNA DAY3
#
# ### BASIC INTRODUCTION  PANDAS BY RISING ODEGUA
#
#
# [Pandas](http://pandas.pydata.org/) is an open source [Python](http://www.python.org/) library for data analysis. Python has always been great for prepping and munging data, but historically it has not been great for analysis - you'd usually end up using [R](http://www.r-project.org/) or loading it into a database and using SQL (or worse, Excel). pandas makes Python great for analysis.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Data Structures
# pandas introduces two new data structures to Python - [Series](http://pandas.pydata.org/pandas-docs/dev/dsintro.html#series) and [DataFrame](http://pandas.pydata.org/pandas-docs/dev/dsintro.html#dataframe), both of which are built on top of [NumPy](http://www.numpy.org/) (this means it's fast).

# %% [markdown]
# ### Series

# %% [markdown]
# A Series is a one-dimensional object similar to an array, list, or column in a table. It will assign a labeled index to each item in the Series. By default, each item will receive an index label from 0 to N, where N is the length of the Series minus one.

# %%
# create a Series with an arbitrary list
s = pd.Series([1, 2.0, "one", 20, 30.7])
s
# Out:
# 0       1
# 1       2
# 2     one
# 3      20
# 4    30.7
# dtype: object

# %% [markdown]
# Alternatively, you can specify an index to use when creating the Series.

# %%
s = pd.Series([7, ' Nigeria', 3.14, -1789710578, 'Happy Eating!'], index=["a", "b", "c", "d", "e"])
s
# Out:
# a                7
# b          Nigeria
# c             3.14
# d      -1789710578
# e    Happy Eating!
# dtype: object

# %%
s['e']
# Out:
# 'Happy Eating!'

# %% [markdown]
# The Series constructor can convert a dictonary as well, using the keys of the dictionary as its index.

# %%
d = {'Chicago': 1000, 
     'New York': 1300,
     'Portland': 900,
     'San Francisco': 1100,
     'Austin': 450,
     'Boston': None}

cities = pd.Series(d)
cities
# Out:
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# Austin            450.0
# Boston              NaN
# dtype: float64

# %% [markdown]
# You can use the index to select specific items from the Series ...

# %%
cities['Austin']
# Out:
# 450.0

# %%
cities[['Chicago', 'Portland']]
# Out:
# Chicago     1000.0
# Portland     900.0
# dtype: float64

# %% [markdown]
# Or you can use boolean indexing for selection.

# %%
large_cities = cities[cities > 1000]
large_cities
# Out:
# New York         1300.0
# San Francisco    1100.0
# dtype: float64

# %% [markdown]
# That last one might be a little weird, so let's make it more clear - `cities < 1000` returns a Series of True/False values, which we then pass to our Series `cities`, returning the corresponding True items.

# %%
less_than_1000 = cities < 1000
print(less_than_1000)
print('\n')
print(cities[less_than_1000])
# Out:
# Chicago          False
# New York         False
# Portland          True
# San Francisco    False
# Austin            True
# Boston           False
# dtype: bool
#
#
# Portland    900.0
# Austin      450.0
# dtype: float64

# %% [markdown]
# You can also change the values in a Series on the fly.

# %%
# changing based on the index
print('Old value:', cities['Chicago'])
cities['Chicago'] = 1500
# Out:
# Old value: 1000.0

# %%
cities
# Out:
# Chicago          1500.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# Austin            450.0
# Boston              NaN
# dtype: float64

# %%
cities
# Out:
# Chicago          1400.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# Austin            450.0
# Boston              NaN
# dtype: float64

# %%
# changing values using boolean logic
print(cities[cities < 1000])
# Out:
# Portland    900.0
# Austin      450.0
# dtype: float64

# %%
cities[cities < 1000] = 0

# %%
cities
# Out:
# Chicago          1500.0
# New York         1300.0
# Portland            0.0
# San Francisco    1100.0
# Austin              0.0
# Boston              NaN
# dtype: float64

# %% [markdown]
# What if you aren't sure whether an item is in the Series?  You can check using idiomatic Python.

# %%
'Boston' in cities
# Out:
# True

# %%
print('Seattle' in cities)
print('San Francisco' in cities)
# Out:
# False
# True

# %% [markdown]
# Mathematical operations can be done using scalars and functions.

# %%
cities
# Out:
# Chicago          1500.0
# New York         1300.0
# Portland            0.0
# San Francisco    1100.0
# Austin              0.0
# Boston              NaN
# dtype: float64

# %%
combined_pop = cities['Chicago'] + cities['New York']

# %%
combined_pop
# Out:
# 2800.0

# %%
# divide city values by 3
cities/2
# Out:
# Chicago          750.0
# New York         650.0
# Portland           0.0
# San Francisco    550.0
# Austin             0.0
# Boston             NaN
# dtype: float64

# %%
# square city values
np.sum(cities)
# Out:
# 3900.0

# %% [markdown]
# You can add two Series together, which returns a union of the two Series with the addition occurring on the shared index values.  Values on either Series that did not have a shared index will produce a NULL/NaN (not a number).

# %%
cities
# Out:
# Chicago          1500.0
# New York         1300.0
# Portland            0.0
# San Francisco    1100.0
# Austin              0.0
# Boston              NaN
# dtype: float64

# %%
# returns a boolean series indicating which values aren't NULL
cities.notnull()
# Out:
# Chicago           True
# New York          True
# Portland          True
# San Francisco     True
# Austin            True
# Boston           False
# dtype: bool

# %%
# use boolean logic to grab the NULL cities
print(cities.isnull())
print('\n')
print(cities[cities.isnull()])
# Out:
# Chicago          False
# New York         False
# Portland         False
# San Francisco    False
# Austin           False
# Boston            True
# dtype: bool
#
#
# Boston   NaN
# dtype: float64

# %% [markdown]
# ## DataFrame
#
# A DataFrame is a tablular data structure comprised of rows and columns, akin to a spreadsheet, database table, or R's data.frame object. You can also think of a DataFrame as a group of Series objects that share an index (the column names).
#
# For the rest of the tutorial, we'll be primarily working with DataFrames.

# %% [markdown]
# ### Reading Data
#
# To create a DataFrame out of common Python data structures, we can pass a dictionary of lists to the DataFrame constructor.
#
# Using the `columns` parameter allows us to tell the constructor how we'd like the columns ordered. By default, the DataFrame constructor will order the columns alphabetically (though this isn't the case when reading from a file - more on that next).

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Bears', 'Bears', 'Bears', 'Packers', 'Packers', 'Lions', 'Lions', 'Lions'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}


football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football
# Out:
#    year     team  wins  losses
# 0  2010    Bears    11       5
# 1  2011    Bears     8       8
# 2  2012    Bears    10       6
# 3  2011  Packers    15       1
# 4  2012  Packers    11       5
# 5  2010    Lions     6      10
# 6  2011    Lions    10       6
# 7  2012    Lions     4      12

# %%
football[football['losses'] < 5]
# Out:
#    year     team  wins  losses
# 3  2011  Packers    15       1

# %% [markdown]
# Much more often, you'll have a dataset you want to read into a DataFrame. Let's go through several common ways of doing so.

# %% [markdown]
# **CSV**
#
# Reading a CSV is as simple as calling the *read_csv* function.

# %%
supermarket_data = pd.read_csv('train.csv')

# %%
supermarket_data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0            11.6             Low Fat                  0.068535  Soft Drinks
# 1            11.6             Low Fat                  0.040912  Soft Drinks
# 2            11.6             Low Fat                  0.041178  Soft Drinks
# 3            11.6             Low Fat                  0.041113  Soft Drinks
# 4            11.6       Ultra Low fat                  0.000000  Soft Drinks
#
#    Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# 0         357.54                      2005               NaN
# 1         355.79                      1994              High
# 2         350.79                      2014               NaN
# 3         355.04                      2016            Medium
# 4         354.79                      2011             Small
#
#   Supermarket_Location_Type   Supermarket_Type  Product_Supermarket_Sales
# 0                 Cluster 3      Grocery Store                     709.08
# 1                 Cluster 3  Supermarket Type1                    6381.69
# 2                 Cluster 2  Supermarket Type1                    6381.69
# 3                 Cluster 3  Supermarket Type2                    2127.23
# 4                 Cluster 2  Supermarket Type1                    2481.77

# %%
supermarket_data[supermarket_data['Product_Price'] > 600]
# Out:
#      Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 44                DRC27            CHUKWUDI017              DRC27_CHUKWUDI017
# 45                DRC27            CHUKWUDI035              DRC27_CHUKWUDI035
# 46                DRC27            CHUKWUDI045              DRC27_CHUKWUDI045
# 159               DRF37            CHUKWUDI017              DRF37_CHUKWUDI017
# 160               DRF37            CHUKWUDI019              DRF37_CHUKWUDI019
# 167               DRF60            CHUKWUDI045              DRF60_CHUKWUDI045
# 208               DRG49            CHUKWUDI017              DRG49_CHUKWUDI017
# 209               DRG49            CHUKWUDI027              DRG49_CHUKWUDI027
# 210               DRG49            CHUKWUDI045              DRG49_CHUKWUDI045
# 343               DRK23            CHUKWUDI017              DRK23_CHUKWUDI017
# 344               DRK23            CHUKWUDI027              DRK23_CHUKWUDI027
# 448               DRP47            CHUKWUDI017              DRP47_CHUKWUDI017
# 474               FDA04            CHUKWUDI017              FDA04_CHUKWUDI017
# 475               FDA04            CHUKWUDI027              FDA04_CHUKWUDI027
# 476               FDA04            CHUKWUDI045              FDA04_CHUKWUDI045
# 501               FDA15            CHUKWUDI017              FDA15_CHUKWUDI017
# 502               FDA15            CHUKWUDI027              FDA15_CHUKWUDI027
# 503               FDA15            CHUKWUDI035              FDA15_CHUKWUDI035
# 504               FDA15            CHUKWUDI045              FDA15_CHUKWUDI045
# 532               FDA27            CHUKWUDI017              FDA27_CHUKWUDI017
# 533               FDA27            CHUKWUDI045              FDA27_CHUKWUDI045
# 564               FDA38            CHUKWUDI019              FDA38_CHUKWUDI019
# 611               FDB03            CHUKWUDI035              FDB03_CHUKWUDI035
# 613               FDB05            CHUKWUDI019              FDB05_CHUKWUDI019
# 614               FDB05            CHUKWUDI027              FDB05_CHUKWUDI027
# 636               FDB15            CHUKWUDI017              FDB15_CHUKWUDI017
# 645               FDB21            CHUKWUDI017              FDB21_CHUKWUDI017
# 646               FDB21            CHUKWUDI027              FDB21_CHUKWUDI027
# 647               FDB21            CHUKWUDI035              FDB21_CHUKWUDI035
# 648               FDB21            CHUKWUDI045              FDB21_CHUKWUDI045
# ...                 ...                    ...                            ...
# 4423              NCM05            CHUKWUDI019              NCM05_CHUKWUDI019
# 4527              NCN55            CHUKWUDI035              NCN55_CHUKWUDI035
# 4642              NCQ06            CHUKWUDI017              NCQ06_CHUKWUDI017
# 4643              NCQ06            CHUKWUDI019              NCQ06_CHUKWUDI019
# 4644              NCQ06            CHUKWUDI027              NCQ06_CHUKWUDI027
# 4645              NCQ06            CHUKWUDI035              NCQ06_CHUKWUDI035
# 4646              NCQ06            CHUKWUDI045              NCQ06_CHUKWUDI045
# 4652              NCQ29            CHUKWUDI017              NCQ29_CHUKWUDI017
# 4653              NCQ29            CHUKWUDI019              NCQ29_CHUKWUDI019
# 4696              NCR38            CHUKWUDI017              NCR38_CHUKWUDI017
# 4697              NCR38            CHUKWUDI019              NCR38_CHUKWUDI019
# 4698              NCR38            CHUKWUDI035              NCR38_CHUKWUDI035
# 4699              NCR38            CHUKWUDI045              NCR38_CHUKWUDI045
# 4717              NCS06            CHUKWUDI019              NCS06_CHUKWUDI019
# 4718              NCS06            CHUKWUDI027              NCS06_CHUKWUDI027
# 344             Medium                 Cluster 3  Supermarket Type3
# 448                NaN                 Cluster 2  Supermarket Type1
# 474                NaN                 Cluster 2  Supermarket Type1
# 475             Medium                 Cluster 3  Supermarket Type3
# 476                NaN                 Cluster 2  Supermarket Type1
# 501                NaN                 Cluster 2  Supermarket Type1
# 502             Medium                 Cluster 3  Supermarket Type3
# 503              Small                 Cluster 2  Supermarket Type1
# 504                NaN                 Cluster 2  Supermarket Type1
# 532                NaN                 Cluster 2  Supermarket Type1
# 533                NaN                 Cluster 2  Supermarket Type1
# 564              Small                 Cluster 1      Grocery Store
# 611              Small                 Cluster 2  Supermarket Type1
# 613              Small                 Cluster 1      Grocery Store
# 614             Medium                 Cluster 3  Supermarket Type3
# 636                NaN                 Cluster 2  Supermarket Type1
# 645                NaN                 Cluster 2  Supermarket Type1
# 646             Medium                 Cluster 3  Supermarket Type3
# 647              Small                 Cluster 2  Supermarket Type1
# 648                NaN                 Cluster 2  Supermarket Type1
# ...                ...                       ...                ...
# 4423             Small                 Cluster 1      Grocery Store
# 4527             Small                 Cluster 2  Supermarket Type1
# 4642               NaN                 Cluster 2  Supermarket Type1
# 4643             Small                 Cluster 1      Grocery Store
# 4644            Medium                 Cluster 3  Supermarket Type3
# 4645             Small                 Cluster 2  Supermarket Type1
# 4646               NaN                 Cluster 2  Supermarket Type1
# 4652               NaN                 Cluster 2  Supermarket Type1
# 4653             Small                 Cluster 1      Grocery Store
# 4696               NaN                 Cluster 2  Supermarket Type1
# 4697             Small                 Cluster 1      Grocery Store
# 4698             Small                 Cluster 2  Supermarket Type1
# 4699               NaN                 Cluster 2  Supermarket Type1
# 4717             Small                 Cluster 1      Grocery Store
# 4718            Medium                 Cluster 3  Supermarket Type3
# 4725               NaN                 Cluster 2  Supermarket Type1
# 4726             Small                 Cluster 1      Grocery Store
# 4754               NaN                 Cluster 2  Supermarket Type1
# 4868               NaN                 Cluster 2  Supermarket Type1
# 4869             Small                 Cluster 2  Supermarket Type1
# 4910               NaN                 Cluster 2  Supermarket Type1
# 4911             Small                 Cluster 1      Grocery Store
# 4912            Medium                 Cluster 3  Supermarket Type3
# 4959               NaN                 Cluster 2  Supermarket Type1
# 4960             Small                 Cluster 1      Grocery Store
# 4961            Medium                 Cluster 3  Supermarket Type3
# 4963               NaN                 Cluster 2  Supermarket Type1
# 4964             Small                 Cluster 1      Grocery Store
# 4965             Small                 Cluster 2  Supermarket Type1
# 4966               NaN                 Cluster 2  Supermarket Type1
#
#       Product_Supermarket_Sales
# 44                      4913.60
# 45                     14126.61
# 46                      3685.20
# 159                     7889.73
# 160                     1972.43
# 167                    10726.04
# 208                    13439.17
# 209                     8552.20
# 210                    17715.27
# 343                    17710.28
# 344                    10752.67
# 448                     6939.30
# 474                    11007.34
# 475                    14244.79
# 476                     7122.40
# 501                    14940.55
# 502                    16185.60
# 503                    16185.60
# 504                    14940.55
# 532                     5113.34
# 533                     2556.67
# 564                     1201.77
# 611                    10815.92
# 613                     1857.58
# 614                    11764.69
# 636                     9887.13
# 645                     4229.49
# 646                    16917.98
# 647                     4229.49
# 648                    13292.70
# ...                         ...
# 4423                    1321.61
# 4527                   13219.46
# 4642                    8287.55
# 4643                     637.50
# 4644                   16575.09
# 4645                   12112.57
# 4646                   14662.58
# 4652                    3904.92
# 4653                    2603.28
# 4696                    9437.72
# 4697                     629.18
# 4698                    1887.54
# 4699                   16987.89
# 4717                     657.48
# 4718                   17751.89
# 4725                    7287.18
# 4726                     662.47
# 4754                   10865.86
# 4868                   11007.34
# 4869                    7122.40
# 4910                    4953.55
# 4911                    1238.39
# 4912                   15479.85
# 4959                    6341.75
# 4960                    1902.52
# 4961                    8244.27
# 4963                   17122.71
# 4964                    1902.52
# 4965                   15220.19
# 4966                    3805.05
#
# [270 rows x 13 columns]

# %%
supermarket_data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0            11.6             Low Fat                  0.068535  Soft Drinks
# 1            11.6             Low Fat                  0.040912  Soft Drinks
# 2            11.6             Low Fat                  0.041178  Soft Drinks
# 3            11.6             Low Fat                  0.041113  Soft Drinks
# 4            11.6       Ultra Low fat                  0.000000  Soft Drinks
#
#    Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# 0         357.54                      2005               NaN
# 1         355.79                      1994              High
# 2         350.79                      2014               NaN
# 3         355.04                      2016            Medium
# 4         354.79                      2011             Small
#
#   Supermarket_Location_Type   Supermarket_Type  Product_Supermarket_Sales
# 0                 Cluster 3      Grocery Store                     709.08
# 1                 Cluster 3  Supermarket Type1                    6381.69
# 2                 Cluster 2  Supermarket Type1                    6381.69
# 3                 Cluster 3  Supermarket Type2                    2127.23
# 4                 Cluster 2  Supermarket Type1                    2481.77

# %%
supermarket_data.describe()
# Out:
#        Product_Weight  Product_Shelf_Visibility  Product_Price  \
# count     4188.000000               4990.000000    4990.000000
# mean        12.908838                  0.066916     391.803796
# std          4.703256                  0.053058     119.378259
# min          4.555000                  0.000000      78.730000
# 25%          8.767500                  0.027273     307.890000
# 50%         12.600000                  0.053564     393.860000
# 75%         17.100000                  0.095358     465.067500
# max         21.350000                  0.328391     667.220000
#
#        Supermarket_Opening_Year  Product_Supermarket_Sales
# count               4990.000000                4990.000000
# mean                2004.783567                6103.520164
# std                    8.283151                4447.333835
# min                 1992.000000                  83.230000
# 25%                 1994.000000                2757.660000
# 50%                 2006.000000                5374.675000
# 75%                 2011.000000                8522.240000
# max                 2016.000000               32717.410000

# %%
supermarket_data.shape
# Out:
# (4990, 13)

# %%
supermarket_data.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0            11.6             Low Fat                  0.068535  Soft Drinks
# 1            11.6             Low Fat                  0.040912  Soft Drinks
# 2            11.6             Low Fat                  0.041178  Soft Drinks
# 3            11.6             Low Fat                  0.041113  Soft Drinks
# 4            11.6       Ultra Low fat                  0.000000  Soft Drinks
#
#    Product_Price  Supermarket_Opening_Year Supermarket _Size  \
# 0         357.54                      2005               NaN
# 1         355.79                      1994              High
# 2         350.79                      2014               NaN
# 3         355.04                      2016            Medium
# 4         354.79                      2011             Small
#
#   Supermarket_Location_Type   Supermarket_Type  Product_Supermarket_Sales
# 0                 Cluster 3      Grocery Store                     709.08
# 1                 Cluster 3  Supermarket Type1                    6381.69
# 2                 Cluster 2  Supermarket Type1                    6381.69
# 3                 Cluster 3  Supermarket Type2                    2127.23
# 4                 Cluster 2  Supermarket Type1                    2481.77

# %%
modern_supermarket = supermarket_data[(supermarket_data['Product_Price'] > 500) & (supermarket_data['Supermarket_Opening_Year'] > 2014)]

# %%
modern_supermarket.shape
# Out:
# (25, 13)

# %%
supermarket_data['Product_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Ultra Low fat', 'Normal Fat'], dtype=object)

# %%
supermarket_data['Product_Fat_Content'].value_counts()
# Out:
# Low Fat          3039
# Normal Fat       1773
# Ultra Low fat     178
# Name: Product_Fat_Content, dtype: int64

# %%
supermarket_data['Supermarket_Type'].unique()
# Out:
# array(['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#        'Supermarket Type3'], dtype=object)

# %%
supermarket_data['Supermarket_Type'].value_counts()
# Out:
# Supermarket Type1    3304
# Grocery Store         724
# Supermarket Type2     500
# Supermarket Type3     462
# Name: Supermarket_Type, dtype: int64
